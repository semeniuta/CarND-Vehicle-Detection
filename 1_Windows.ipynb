# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from glob import glob

# %%
import vdetect

# %%
test_images = [mpimg.imread(f) for f in glob('test_images/*.jpg')]

main_region = vdetect.define_main_region_custom()
mr_x0, mr_y0, mr_x1, mr_y1 = main_region

# %%
im = test_images[0]

plt.imshow(
    vdetect.draw_boxes(
        im,
        [main_region]
    )
)

print(main_region)
# Out:
# (0, 138, 1280, 650)

# %%
plt.imshow(
    vdetect.draw_boxes(
        im,
        vdetect.window_loop(512, 256, mr_x0, mr_y0, mr_x1, mr_y1)
    )
)

# %%
plt.imshow(
    vdetect.draw_boxes(
        im,
        vdetect.window_loop(256, 128, mr_x0, mr_y0, mr_x1, mr_y1)
    )
)

# %%
plt.imshow(
    vdetect.draw_boxes(
        im,
        vdetect.window_loop(128, 64, mr_x0, mr_y0+128, mr_x1, mr_y1-64)
    )
)

# %%
plt.imshow(
    vdetect.draw_boxes(
        im,
        vdetect.window_loop(64, 32, mr_x0, mr_y0+128+64, mr_x1, mr_y1-64-64)
    )
)

# %%
plt.imshow(
    vdetect.draw_boxes(
        im,
        vdetect.window_loop(256, 64, mr_x0, mr_y0, mr_x1, mr_y1)
    )
)

# %%
vdetect.window_loop(4, 2, 0, 0, 16, 8)
# Out:
# array([[ 0,  0,  3,  3],
#        [ 2,  0,  5,  3],
#        [ 4,  0,  7,  3],
#        [ 6,  0,  9,  3],
#        [ 8,  0, 11,  3],
#        [10,  0, 13,  3],
#        [12,  0, 15,  3],
#        [ 0,  2,  3,  5],
#        [ 2,  2,  5,  5],
#        [ 4,  2,  7,  5],
#        [ 6,  2,  9,  5],
#        [ 8,  2, 11,  5],
#        [10,  2, 13,  5],
#        [12,  2, 15,  5],
#        [ 0,  4,  3,  7],
#        [ 2,  4,  5,  7],
#        [ 4,  4,  7,  7],
#        [ 6,  4,  9,  7],
#        [ 8,  4, 11,  7],
#        [10,  4, 13,  7],
#        [12,  4, 15,  7]])
