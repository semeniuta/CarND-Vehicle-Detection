# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from glob import glob

# %%
import vdetect

# %%
test_images = [mpimg.imread(f) for f in glob('test_images/*.jpg')]

# %%
im = test_images[0]
bbox = (800, 400, 1200, 500)
plt.imshow( vdetect.window_region(im, bbox) )

# %%
plt.imshow( vdetect.draw_boxes(im, [bbox]) )

# %%
vdetect.window_loop(4, 2, 0, 0, 64, 50)
# Out:
# array([[ 0,  0,  3,  3],
#        [ 2,  0,  5,  3],
#        [ 4,  0,  7,  3],
#        ...,
#        [56, 46, 59, 49],
#        [58, 46, 61, 49],
#        [60, 46, 63, 49]])

# %%
plt.imshow(
    vdetect.draw_boxes(
        im,
        vdetect.window_loop(256, 128, 0, 0, im.shape[1], im.shape[0])
    )
)
