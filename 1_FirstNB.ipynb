# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from glob import glob

# %%
import vdetect

# %%
test_images = [mpimg.imread(f) for f in glob('test_images/*.jpg')]

# %%
im = test_images[0]
bbox = (800, 400, 1200, 500)
plt.imshow( vdetect.window_region(im, bbox) )

# %%
plt.imshow(
    vdetect.draw_boxes(
        im,
        vdetect.window_loop(512, 256, 0, 0, im.shape[1], im.shape[0])
    )
)

# %%
main_region = vdetect.define_main_region_custom()

plt.imshow(
    vdetect.draw_boxes(
        im,
        [main_region]
    )
)

print(main_region)
# Out:
# (0, 138, 1280, 650)
